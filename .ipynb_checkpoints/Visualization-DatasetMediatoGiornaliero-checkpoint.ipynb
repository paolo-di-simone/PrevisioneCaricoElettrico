# %% [markdown]
# # Analisi minimi, massimi, media e deviazione standard

# %%
import pandas as pd
import os

# %%
dataset_path = os.path.join("Dataset", "dataset_giornaliero.csv")
df = pd.read_csv(dataset_path)

# %%
df.head()
# Out:
#    Year  Month  Day  P_CabinePower_L1  P L1 WS Emergency Light  P L1 WS Light  \
# 0  2021      1    1         79.254670               202.378472            0.0
# 1  2021      1    2         81.984566               201.883681            0.0
# 2  2021      1    3         82.033252               203.032986            0.0
# 3  2021      1    4         81.717328               202.347222            0.0
# 4  2021      1    5         81.505118               201.762153            0.0
#
#    P L1 WS FanCoil  P L1 WS FM  P_HeatPump  P L2 WS Emergency Light  ...  \
# 0              0.0  610.338542  566.719845               290.340278  ...
# 1              0.0  603.321181  469.166134               290.496528  ...
# 2              0.0  613.644097  573.911469               291.067708  ...
# 3              0.0  612.317708  578.608768               290.548611  ...
# 4              0.0  623.968750  583.649437               290.439236  ...
#
#    P L3 WS FM  P WS Emergency Light  P WS Light  P WS FanCoil      P WS FM  \
# 0  345.484375            803.616319  317.605903           0.0  1151.692708
# 1  344.635417            803.868056  318.831597           0.0  1145.562500
# 2  350.567708            806.015625  318.300347           0.0  1162.996528
# 3  342.701389            803.664931  317.230903           0.0  1148.847222
# 4  350.635417            803.755208  317.972222           0.0  1177.281250
#
#       Timestamp     PowerL1      PowerL2     PowerL3   TotalPower
# 0  1.609456e+09  891.971684  1054.002831  978.003971  2923.978486
# 1  1.609542e+09  887.189428   957.277245  976.292341  2820.759013
# 2  1.609628e+09  898.710335  1061.906260  985.339404  2945.956000
# 3  1.609715e+09  896.382259  1066.537588  974.247660  2937.167506
# 4  1.609801e+09  907.236021  1071.567840  985.323366  2964.127226
#
# [5 rows x 27 columns]

# %%
single_phase = ["P_CabinePower_L1", "P_HeatPump", "P_CabineLight_L3"]
three_phase = ["P WS Emergency Light", "P WS Light", "P WS FanCoil", "P WS FM"]

fields_sum = ["PowerL1", "PowerL2", "PowerL3", "TotalPower"]

L1 = ["P_CabinePower_L1", "P L1 WS Emergency Light", "P L1 WS Light", "P L1 WS FanCoil", "P L1 WS FM"]
L2 = ["P_HeatPump", "P L2 WS Emergency Light", "P L2 WS Light", "P L2 WS FanCoil", "P L2 WS FM"]
L3 = ["P_CabineLight_L3", "P L3 WS Emergency Light", "P L3 WS Light", "P L3 WS FanCoil", "P L3 WS FM"]

# %%
rounded_describe = df.describe().round(decimals=2)

# %%
rounded_describe[fields_sum]
# Out:
#        PowerL1  PowerL2  PowerL3  TotalPower
# count   479.00   479.00   479.00      479.00
# mean   1694.28  2043.90  1311.28     5049.46
# std     483.88   685.25   337.22     1314.57
# min     864.09   813.45   487.85     2540.00
# 25%    1344.79  1629.92  1076.98     4127.61
# 50%    1643.11  1875.57  1252.38     4852.06
# 75%    1919.77  2224.85  1482.53     5706.91
# max    4129.57  5476.08  2458.88     9361.84

# %%
rounded_describe[L1]
# Out:
#        P_CabinePower_L1  P L1 WS Emergency Light  P L1 WS Light  \
# count            479.00                   479.00         479.00
# mean              84.85                   599.37         261.04
# std                5.48                   182.01          33.99
# min               76.32                   158.24           0.00
# 25%               82.85                   478.19         262.91
# 50%               83.64                   612.73         265.45
# 75%               84.54                   720.60         267.15
# max              111.46                  1197.99         328.21
#
#        P L1 WS FanCoil  P L1 WS FM
# count           479.00      479.00
# mean             11.58      737.45
# std              27.52      362.86
# min               0.00      270.00
# 25%               0.00      490.92
# 50%               0.00      624.46
# 75%               0.24      895.87
# max             133.13     2581.56

# %%
rounded_describe[L2]
# Out:
#        P_HeatPump  P L2 WS Emergency Light  P L2 WS Light  P L2 WS FanCoil  \
# count      479.00                   479.00         479.00            479.0
# mean       253.90                   797.04         279.09              0.0
# std        198.56                   175.25          49.80              0.0
# min          5.97                   290.34           0.00              0.0
# 25%         58.26                   684.01         251.04              0.0
# 50%        250.53                   801.96         289.14              0.0
# 75%        361.38                   905.34         295.36              0.0
# max        816.72                  1423.64         404.70              0.0
#
#        P L2 WS FM
# count      479.00
# mean       713.87
# std        479.83
# min         90.00
# 25%        467.37
# 50%        547.67
# 75%        792.26
# max       3612.37

# %%
rounded_describe[L3]
# Out:
#        P_CabineLight_L3  P L3 WS Emergency Light  P L3 WS Light  \
# count            479.00                   479.00         479.00
# mean               2.82                   387.25         258.14
# std                2.02                    92.57          59.89
# min                0.00                   131.94           0.00
# 25%                0.69                   341.21         203.18
# 50%                2.99                   384.77         262.58
# 75%                4.43                   436.04         312.50
# max               10.72                   719.07         436.30
#
#        P L3 WS FanCoil  P L3 WS FM
# count           479.00      479.00
# mean             21.94      641.13
# std              42.24      315.34
# min               0.00       95.69
# 25%               0.00      407.91
# 50%               0.00      551.86
# 75%               9.31      794.96
# max             148.88     1727.92

# %% [markdown]
# # Plot curve di carico

# %%
from scipy.signal import resample
import numpy as np
from datetime import datetime
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import os
import pandas as pd
import calendar

# %%
color1 = "#c8a2c8" # lilla
color2 = "#6495ed" # blu fiordaliso
color3 = "#93ccea" # blu fiordaliso chiaro
color4 = "#000000" # nero
color5 = "#2271b3" # blu cielo

# %%
SECONDS_IN_DAY = 60*60*24
SECONDS_IN_MONTH = 60*60*24*31
SECONDS_IN_YEAR = 60*60*24*31*12

# %%
plot_path = os.path.join("Plot", "PlotDatasetMediato")
plot_path = os.path.join(plot_path, "DistribuzioneCarichi")
dataset_path = os.path.join("Dataset", "dataset_giornaliero.csv")

# %%
counter = 0
def make_path(base_path, file_name):
    global counter
    counter += 1
    file_name = str(counter) + "-" + file_name  
    return os.path.join(base_path, file_name)

# %%
df = pd.read_csv(dataset_path)

# %%
def get_x_ticks_from_delta(start, end, len_x):
    delta = end - start
    delta_s = delta.total_seconds()
    delta_s += 1
    
    if delta_s <= SECONDS_IN_DAY:
        step = int(delta_s//60//60) + 1
        positions = np.linspace(0,len_x,step)
        dist = positions[1] - positions[0]
        positions = [x + int(dist//2) for x in positions]
        positions = positions[:-1]
        labels = [str(i)+":00" for i in range(0,len(positions))]
        
    elif delta_s <= SECONDS_IN_MONTH:
        step = int(delta_s//60//60//24) + 1
        positions = np.linspace(0,len_x,step)
        dist = positions[1] - positions[0]
        positions = [x + int(dist//2) for x in positions]
        positions = positions[:-1]
        labels = [str(i+1) for i in range(0,len(positions))]
        
    else:
        step = int(delta_s//60//60//24//28)
        positions = np.linspace(0,len_x,step)
        dist = positions[1] - positions[0]
        positions = [x + int(dist//2) for x in positions]
        positions = positions[:-1]
        labels = [str(i+1) for i in range(0,len(positions))]
        
    return positions, labels

# %%
def get_data(data, start, end, field):
    df_tmp = data[
        (data["Year"] >= start.year) & (data["Year"] <= end.year) &
        (data["Month"] >= start.month) & (data["Month"] <= end.month) &
        (data["Day"] >= start.day) & (data["Day"] <= end.day)
    ]
    return list(df_tmp[field])

# %% [markdown]
# ### Plot singolo

# %%
def plot_single_load_distribution(data, start, end, field, c1, c2, title, xlabel, ylabel, dim, plot_path):
                
    plt.figure(figsize=dim) 
    plt.grid(color=c2, linestyle="-", linewidth="0.2", axis="y")
    
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    
    yvalue = get_data(data, start, end, field)
    len_x = len(yvalue)
    xvalue = [x for x in range(0,len_x)]  
    
    #plt.axvspan(3, 6, color='red', alpha=0.5)
    
    positions, labels = get_x_ticks_from_delta(start, end, len_x)
    plt.xticks(positions, labels, rotation=45)
    
    plt.plot(xvalue, yvalue, color=c1, linewidth="1.5")
    
    file_name = "".join(title.lower()).replace(" ", "_")
    path = make_path(plot_path, file_name)
    plt.savefig(path, bbox_inches='tight', transparent=True)
    plt.show()

# %%
start = datetime(2020, 1, 1, 0, 0, 0)
end = datetime(2022, 12, 31, 23, 59, 59)
title = "Curva di carico giornaliera"
xlabel = "TotalPower"
ylabel = "W"
dim = (30,10)
plot_single_load_distribution(df, start, end, "TotalPower", color5, color4, title, xlabel, ylabel, dim, plot_path)

# %% [markdown]
# ### Plot multiplo

# %%
def plot_multiple_load_distribution(data, start, end, fields, c, title, ylabel, dim, plot_path):
                
    plt.figure(figsize=dim) 
    plt.grid(color=c, linestyle="-", linewidth="0.2", axis="y")
    
    plt.title(title)
    plt.ylabel(ylabel)
    
    for field in fields:
        yvalue = get_data(data, start, end, field)
        len_x = len(yvalue)
        xvalue = [x for x in range(0,len_x)]  
        plt.plot(xvalue, yvalue, linewidth="1.5", label=field)
    
    
    positions, labels = get_x_ticks_from_delta(start, end, len_x)
    plt.xticks(positions, labels, rotation=45)
    
    plt.legend()
    
    file_name = "".join(title.lower()).replace(" ", "_")
    path = make_path(plot_path, file_name)
    plt.savefig(path, bbox_inches='tight', transparent=True)
    plt.show()

# %%
single_phase = ["P_CabinePower_L1", "P_HeatPump", "P_CabineLight_L3"]
three_phase = ["P WS Emergency Light", "P WS Light", "P WS FanCoil", "P WS FM"]

fields_sum = ["PowerL1", "PowerL2", "PowerL3", "TotalPower"]

L1 = ["P_CabinePower_L1", "P L1 WS Emergency Light", "P L1 WS Light", "P L1 WS FanCoil", "P L1 WS FM"]
L2 = ["P_HeatPump", "P L2 WS Emergency Light", "P L2 WS Light", "P L2 WS FanCoil", "P L2 WS FM"]
L3 = ["P_CabineLight_L3", "P L3 WS Emergency Light", "P L3 WS Light", "P L3 WS FanCoil", "P L3 WS FM"]

# %%
start = datetime(2021, 5, 1, 0, 0, 0)
end = datetime(2021, 5, 30, 23, 59, 59)
title = "Curva di carico giornaliera"
ylabel = "W"
dim = (15,5)
plot_multiple_load_distribution(df, start, end, fields_sum, color4, title, ylabel, dim, plot_path)
